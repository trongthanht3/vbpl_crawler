# %%
import pandas as pd

df_train = pd.read_csv('training_data/train.csv')
df_train
# Out:
#                              question_id  \
# 0               5733be284776f4190066117e
# 1               5733be284776f4190066117f
# 2               5733be284776f41900661180
# 3               5733be284776f41900661181
# 4               5733be284776f41900661182
# ...                                  ...
# 140764  94ae502e5bf5a3befe8098db04624096
# 140765  817afb853f193ffe938887d569675cf0
# 140766  a6f164cc19e193abe5f0323c807081be
# 140767  7e9a91a8b157ead81059304ae538cc04
# 140768  915c522bf6ffe2d21e4bf9f4110c8596
#
#                                                  question  \
# 0       Có gì ngồi trên đầu trang của Tòa nhà Chính tạ...
# 1       là những gì ở phía trước của Notre Dame Tòa nh...
# 2       Vương Cung Thánh Đường của trái tim Thánh tại ...
# 3                        các Grotto tại Notre Dame là gì?
# 4       Mà đã bị cáo buộc Đức Trinh Nữ Maria xuất hiện...
# ...                                                   ...
# ...

# %%
df_test = pd.read_csv("training_data/test.csv")
df_test
# Out:
#                           question_id  \
# 0    596b347b50ab4edb6c8535212ec58910
# 1    4cc72795afaeace93747cc62b162f85c
# 2    4cc72795afaeace93747cc62b162f85c
# 3    4cc72795afaeace93747cc62b162f85c
# 4    e3f19447a5df1614eeb6f7e3e3faa754
# ..                                ...
# 995  6088765b2e502c7d900a3f9a2f82f2b4
# 996  6088765b2e502c7d900a3f9a2f82f2b4
# 997  e3269fcc763ea92e5bab69ca67d88dd9
# 998  e3269fcc763ea92e5bab69ca67d88dd9
# 999  e3269fcc763ea92e5bab69ca67d88dd9
#
#                                               question            law_id  \
# 0    Người bị tạm giam, tạm giữ có được đi bầu cử H...      85/2015/qh13
# 1     Chuẩn mực kế toán theo quy định cũ gồm những gì?      03/2003/qh11
# 2     Chuẩn mực kế toán theo quy định cũ gồm những gì?      03/2003/qh11
# 3     Chuẩn mực kế toán theo quy định cũ gồm những gì?      03/2003/qh11
# 4     Có phải lập hồ sơ lâm sản khi mở xưởng gỗ không?      16/2017/qh14
# ...
